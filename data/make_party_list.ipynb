# %%
# Data Converter
# Input Data:
#     https://www.elections.ca/content.aspx?section=res&dir=rep/off/42gedata&document=summary&lang=e
#     Table 8: Number of valid votes by political affiliation
#     Table 11: Voting results by electoral district
#     Table 12: List of candidates by electoral district and individual results
#
# Output Data
#     all_parties_2015.csv - complete list of the parties that participated in 2015 elections
#     winning_parties_2015.csv - only the list of winning parties of 2015 elections
#
# Output Data Spec:
#     'Id' - unique 2-4 charcters Id that can be use as an index or a key
#     'Long Name (en)', 'Long Name (fr)' - full name of a party as in parties related data files presented by Elections Canada
#     'Short Name (en)', 'Short Name (fr)' - short name (not always) of a party as used in data files related to candidates
#     'Candidate Suffix' - a suffix appended to a candidate name in candidates related data files
#     'Custom Name' - names of winning parties used in our project data files/frames

# %%
# Depedences and initialization
import pandas as pd

# Files
votes_party_fname = 'table_tableau08.csv'
voting_results_fname = 'table_tableau11.csv'
candidates_fname = 'table_tableau12.csv'
parties_fname = 'all_parties_2015.csv'
winners_fname = 'winning_parties_2015.csv'

# %%
# Reading input data
votes_party_df = pd.read_csv(votes_party_fname)

# %%
parties_df = pd.DataFrame(votes_party_df['Political affiliation/Appartenance politique'])

parties_df['Id'] = pd.Series([
    'ATN',   'AA',  'BC', 'CAN', 'CAP', # 0 - 4
    'CHP',  'COM', 'CPC', 'DAP',  'FD', # 5 - 9
    'GRN',  'LIB', 'LTN', 'MAR',  'ML', # 10 - 14
    'NDP', 'PACT', 'PIR',  'PC', 'RHI', # 15 - 19
    'SEN',  'BDG', 'UNI', 'IND', 'NOA'  # 20 - 24
])

parties_df['Long Name (en)'] = parties_df.iloc[:, 0].map(lambda s: s.split('/')[0])
parties_df['Long Name (fr)'] = parties_df.iloc[:, 0].map(lambda s: s.split('/')[1])
parties_df.drop(columns=['Political affiliation/Appartenance politique'], inplace=True)

parties_df
# Out:
#       Id                                     Long Name (en)  \
# 0    ATN                              Alliance of the North
# 1     AA  Animal Alliance Environment Voters Party of Ca...
# 2     BC                                     Bloc Québécois
# 3    CAN                                       Canada Party
# 4    CAP                              Canadian Action Party
# 5    CHP                 Christian Heritage Party of Canada
# 6    COM                          Communist Party of Canada
# 7    CPC                       Conservative Party of Canada
# 8    DAP             Democratic Advancement Party of Canada
# 9     FD                               Forces et Démocratie
# 10   GRN                              Green Party of Canada
# 11   LIB                            Liberal Party of Canada
# 12   LTN                        Libertarian Party of Canada
# 13   MAR                                    Marijuana Party
# 14    ML                   Marxist-Leninist Party of Canada
# 15   NDP                               New Democratic Party
# 16  PACT  Party for Accountability, Competency and Trans...
# 17   PIR                             Pirate Party of Canada
# 18    PC                         Progressive Canadian Party
# 19   RHI                                   Rhinoceros Party
# 20   SEN                            Seniors Party of Canada
# 21   BDG                         The Bridge Party of Canada
# 22   UNI                             United Party of Canada
# 23   IND                                        Independent
# 24   NOA                                     No Affiliation
#
#                                        Long Name (fr)
# 0                                    Alliance du Nord
# 1   Animal Alliance Environment Voters Party of Ca...
# 2                                      Bloc Québécois
# 3                                        Parti Canada
# 4                             Parti action canadienne
# 5              Parti de l'Héritage Chrétien du Canada
# 6                          Parti communiste du Canada
# 7                        Parti conservateur du Canada
# 8   Parti pour l'Avancement de la Démocratie au Ca...
# 9                                Forces et Démocratie
# 10                            Le Parti Vert du Canada
# 11                            Parti libéral du Canada
# 12                        Parti Libertarien du Canada
# 13                                    Parti Marijuana
# 14                 Parti Marxiste-Léniniste du Canada
# 15                         Nouveau Parti démocratique
# 16  Parti pour la Responsabilisation, la Compétenc...
# 17                             Parti Pirate du Canada
# 18                        Parti Progressiste Canadien
# 19                                   Parti Rhinocéros
# 20                          Parti des aînés du Canada
# 21         Parti pour nouer des liens entre Canadiens
# 22                                Parti Uni du Canada
# 23                                        Indépendant
# 24                                Aucune appartenance

# %%
candidates_df = pd.read_csv(candidates_fname)

# %%
candidates_df['Short Name (fr)'] = candidates_df['Candidate/Candidat'].map(lambda s: s.rsplit('/')[-1])
short_names_df = pd.DataFrame(candidates_df['Short Name (fr)'].unique())
short_names_df.columns = ['Short Name (fr)']
short_names_df['Id'] = pd.Series([
     'LIB', 'NOA', 'NDP', 'CPC', 'GRN',
      'FD', 'COM', 'CHP', 'IND',  'ML',
     'RHI', 'LTN',  'BC', 'ATN', 'UNI',
      'AA', 'CAP',  'PC', 'MAR', 'PIR',
    'PACT', 'SEN', 'BDG', 'CAN', 'DAP'
])
short_names_df.iloc[15, 0] = 'Animal Alliance/Environment Voters'
short_names_df
# Out:
#                                       Short Name (fr)    Id
# 0                                             Libéral   LIB
# 1                                 Aucune appartenance   NOA
# 2                      NPD-Nouveau Parti démocratique   NDP
# 3                                        Conservateur   CPC
# 4                                          Parti Vert   GRN
# 5   Forces et Démocratie - Allier les forces de no...    FD
# 6                                          Communiste   COM
# 7                        Parti de l'Héritage Chrétien   CHP
# 8                                         Indépendant   IND
# 9                                  Marxiste-Léniniste    ML
# 10                                         Rhinocéros   RHI
# 11                                        Libertarien   LTN
# 12                                     Bloc Québécois    BC
# 13                                                ADN   ATN
# 14                                          Parti Uni   UNI
# 15                 Animal Alliance/Environment Voters    AA
# 16                                                PAC   CAP
# 17                                           Parti PC    PC
# 18                                  Radical Marijuana   MAR
# 19                                             Pirate   PIR
# 20                                               PRCT  PACT
# 21                                    Parti des aînés   SEN
# 22                                            Le Lien   BDG
# 23                                       Parti Canada   CAN
# 24                        Avancement de la Démocratie   DAP

# %%
parties_list = []
first_candidates_list = []

for i, row in candidates_df.iterrows():
    party_fr = row['Candidate/Candidat'].rsplit('/')[-1]
    if not party_fr in parties_list:
        parties_list.append(party_fr)
        first_candidates_list.append(row['Candidate/Candidat'])

print(first_candidates_list)
# Out:
# ['Ken McDonald Liberal/Libéral', 'Scott Andrews ** No Affiliation/Aucune appartenance', 'Jeannie Baldwin NDP-New Democratic Party/NPD-Nouveau Parti démocratique', 'Lorraine E. Barnett Conservative/Conservateur', 'Krista Byrne-Puumala Green Party/Parti Vert', 'Jennifer McCreath Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions', 'Sean Burton Communist/Communiste', "Christene Squires Christian Heritage Party/Parti de l'Héritage Chrétien", 'Alexander J. MacKenzie Independent/Indépendant', 'Allan Bezanson Marxist-Leninist/Marxiste-Léniniste', 'Megan Brown-Hodges Rhinoceros/Rhinocéros', 'Wayne James Hiscock Libertarian/Libertarien', 'Luc Ferland Bloc Québécois/Bloc Québécois', 'François Belanger ATN/ADN', 'Bob Kesic United Party/Parti Uni', 'Kyle Bowles Animal Alliance/Environment Voters/Animal Alliance/Environment Voters', 'Jeff Sakula CAP/PAC', 'Rob Wolvin PC Party/Parti PC', 'Kornelis Klevering Radical Marijuana/Radical Marijuana', 'Duncan Bell Pirate/Pirate', 'Michael Nicula PACT/PRCT', 'Margaret Leigh Fairbairn Seniors Party/Parti des aînés', 'David Berlin The Bridge/Le Lien', 'Jim Pankiw Canada Party/Parti Canada', 'Fahed Khalid Democratic Advancement/Avancement de la Démocratie']

# %%
short_names_df['Short Name (en)'] = pd.Series([
    'Liberal', 'No Affiliation', 'NDP-New Democratic Party', 'Conservative', 'Green Party',
    'Forces et Démocratie - Allier les forces de nos régions', 'Communist', 'Christian Heritage Party', 'Independent',
    'Marxist-Leninist',
     'Rhinoceros', 'Libertarian',  'Bloc Québécois', 'ATN', 'United Party',
      'Animal Alliance/Environment Voters', 'CAP',  'PC Party', 'Marijuana', 'Pirate',
    'PACT', 'Seniors Party', 'The Bridge', 'Canada Party', 'Democratic Advancement'
])
short_names_df['Candidate Suffix'] = ' ' + short_names_df['Short Name (en)'] + '/' + short_names_df['Short Name (fr)']
short_names_df
# Out:
#                                       Short Name (fr)    Id  \
# 0                                             Libéral   LIB
# 1                                 Aucune appartenance   NOA
# 2                      NPD-Nouveau Parti démocratique   NDP
# 3                                        Conservateur   CPC
# 4                                          Parti Vert   GRN
# 5   Forces et Démocratie - Allier les forces de no...    FD
# 6                                          Communiste   COM
# 7                        Parti de l'Héritage Chrétien   CHP
# 8                                         Indépendant   IND
# 9                                  Marxiste-Léniniste    ML
# 10                                         Rhinocéros   RHI
# 11                                        Libertarien   LTN
# 12                                     Bloc Québécois    BC
# 13                                                ADN   ATN
# 14                                          Parti Uni   UNI
# 15                 Animal Alliance/Environment Voters    AA
# 16                                                PAC   CAP
# 17                                           Parti PC    PC
# 18                                  Radical Marijuana   MAR
# 19                                             Pirate   PIR
# 20                                               PRCT  PACT
# 21                                    Parti des aînés   SEN
# 22                                            Le Lien   BDG
# 23                                       Parti Canada   CAN
# 24                        Avancement de la Démocratie   DAP
#
#                                       Short Name (en)  \
# 0                                             Liberal
# 1                                      No Affiliation
# 2                            NDP-New Democratic Party
# 3                                        Conservative
# 4                                         Green Party
# 5   Forces et Démocratie - Allier les forces de no...
# 6                                           Communist
# 7                            Christian Heritage Party
# 8                                         Independent
# 9                                    Marxist-Leninist
# 10                                         Rhinoceros
# 11                                        Libertarian
# 12                                     Bloc Québécois
# 13                                                ATN
# 14                                       United Party
# 15                 Animal Alliance/Environment Voters
# 16                                                CAP
# 17                                           PC Party
# 18                                          Marijuana
# 19                                             Pirate
# 20                                               PACT
# 21                                      Seniors Party
# 22                                         The Bridge
# 23                                       Canada Party
# 24                             Democratic Advancement
#
#                                      Candidate Suffix
# 0                                     Liberal/Libéral
# 1                  No Affiliation/Aucune appartenance
# 2    NDP-New Democratic Party/NPD-Nouveau Parti dé...
# 3                           Conservative/Conservateur
# 4                              Green Party/Parti Vert
# 5    Forces et Démocratie - Allier les forces de n...
# 6                                Communist/Communiste
# 7    Christian Heritage Party/Parti de l'Héritage ...
# 8                             Independent/Indépendant
# 9                 Marxist-Leninist/Marxiste-Léniniste
# 10                              Rhinoceros/Rhinocéros
# 11                            Libertarian/Libertarien
# 12                      Bloc Québécois/Bloc Québécois
# 13                                            ATN/ADN
# 14                             United Party/Parti Uni
# 15   Animal Alliance/Environment Voters/Animal All...
# 16                                            CAP/PAC
# 17                                  PC Party/Parti PC
# 18                        Marijuana/Radical Marijuana
# 19                                      Pirate/Pirate
# 20                                          PACT/PRCT
# 21                      Seniors Party/Parti des aînés
# 22                                 The Bridge/Le Lien
# 23                          Canada Party/Parti Canada
# 24   Democratic Advancement/Avancement de la Démoc...

# %%
parties_df = pd.merge(parties_df, short_names_df, how='left', on='Id')

parties_df['Custom Name'] = ''
parties_df.loc[parties_df['Id'] == 'BC', 'Custom Name'] = 'Bloc Québécois'
parties_df.loc[parties_df['Id'] == 'CPC', 'Custom Name'] = 'Conservative'
parties_df.loc[parties_df['Id'] == 'GRN', 'Custom Name'] = 'Green Party'
parties_df.loc[parties_df['Id'] == 'LIB', 'Custom Name'] = 'Liberal'
parties_df.loc[parties_df['Id'] == 'NDP', 'Custom Name'] = 'NDP'

# %%
parties_df.to_csv(parties_fname, index=False, encoding='utf-8')
parties_df
# Out:
#       Id                                     Long Name (en)  \
# 0    ATN                              Alliance of the North
# 1     AA  Animal Alliance Environment Voters Party of Ca...
# 2     BC                                     Bloc Québécois
# 3    CAN                                       Canada Party
# 4    CAP                              Canadian Action Party
# 5    CHP                 Christian Heritage Party of Canada
# 6    COM                          Communist Party of Canada
# 7    CPC                       Conservative Party of Canada
# 8    DAP             Democratic Advancement Party of Canada
# 9     FD                               Forces et Démocratie
# 10   GRN                              Green Party of Canada
# 11   LIB                            Liberal Party of Canada
# 12   LTN                        Libertarian Party of Canada
# 13   MAR                                    Marijuana Party
# 14    ML                   Marxist-Leninist Party of Canada
# 15   NDP                               New Democratic Party
# 16  PACT  Party for Accountability, Competency and Trans...
# 17   PIR                             Pirate Party of Canada
# 18    PC                         Progressive Canadian Party
# 19   RHI                                   Rhinoceros Party
# 20   SEN                            Seniors Party of Canada
# 21   BDG                         The Bridge Party of Canada
# 22   UNI                             United Party of Canada
# 23   IND                                        Independent
# 24   NOA                                     No Affiliation
#
#                                        Long Name (fr)  \
# 0                                    Alliance du Nord
# 1   Animal Alliance Environment Voters Party of Ca...
# 2                                      Bloc Québécois
# 3                                        Parti Canada
# 4                             Parti action canadienne
# 5              Parti de l'Héritage Chrétien du Canada
# 6                          Parti communiste du Canada
# 7                        Parti conservateur du Canada
# 8   Parti pour l'Avancement de la Démocratie au Ca...
# 9                                Forces et Démocratie
# 10                            Le Parti Vert du Canada
# 11                            Parti libéral du Canada
# 12                        Parti Libertarien du Canada
# 13                                    Parti Marijuana
# 14                 Parti Marxiste-Léniniste du Canada
# 15                         Nouveau Parti démocratique
# 16  Parti pour la Responsabilisation, la Compétenc...
# 17                             Parti Pirate du Canada
# 18                        Parti Progressiste Canadien
# 19                                   Parti Rhinocéros
# 20                          Parti des aînés du Canada
# 21         Parti pour nouer des liens entre Canadiens
# 22                                Parti Uni du Canada
# 23                                        Indépendant
# 24                                Aucune appartenance
#
#                                       Short Name (fr)  \
# 0                                                 ADN
# 1                  Animal Alliance/Environment Voters
# 2                                      Bloc Québécois
# 3                                        Parti Canada
# 4                                                 PAC
# 5                        Parti de l'Héritage Chrétien
# 6                                          Communiste
# 7                                        Conservateur
# 8                         Avancement de la Démocratie
# 9   Forces et Démocratie - Allier les forces de no...
# 10                                         Parti Vert
# 11                                            Libéral
# 12                                        Libertarien
# 13                                  Radical Marijuana
# 14                                 Marxiste-Léniniste
# 15                     NPD-Nouveau Parti démocratique
# 16                                               PRCT
# 17                                             Pirate
# 18                                           Parti PC
# 19                                         Rhinocéros
# 20                                    Parti des aînés
# 21                                            Le Lien
# 22                                          Parti Uni
# 23                                        Indépendant
# 24                                Aucune appartenance
#
#                                       Short Name (en)  \
# 0                                                 ATN
# 1                  Animal Alliance/Environment Voters
# 2                                      Bloc Québécois
# 3                                        Canada Party
# 4                                                 CAP
# 5                            Christian Heritage Party
# 6                                           Communist
# 7                                        Conservative
# 8                              Democratic Advancement
# 9   Forces et Démocratie - Allier les forces de no...
# 10                                        Green Party
# 11                                            Liberal
# 12                                        Libertarian
# 13                                          Marijuana
# 14                                   Marxist-Leninist
# 15                           NDP-New Democratic Party
# 16                                               PACT
# 17                                             Pirate
# 18                                           PC Party
# 19                                         Rhinoceros
# 20                                      Seniors Party
# 21                                         The Bridge
# 22                                       United Party
# 23                                        Independent
# 24                                     No Affiliation
#
#                                      Candidate Suffix     Custom Name
# 0                                             ATN/ADN
# 1    Animal Alliance/Environment Voters/Animal All...
# 2                       Bloc Québécois/Bloc Québécois  Bloc Québécois
# 3                           Canada Party/Parti Canada
# 4                                             CAP/PAC
# 5    Christian Heritage Party/Parti de l'Héritage ...
# 6                                Communist/Communiste
# 7                           Conservative/Conservateur    Conservative
# 8    Democratic Advancement/Avancement de la Démoc...
# 9    Forces et Démocratie - Allier les forces de n...
# 10                             Green Party/Parti Vert     Green Party
# 11                                    Liberal/Libéral         Liberal
# 12                            Libertarian/Libertarien
# 13                        Marijuana/Radical Marijuana
# 14                Marxist-Leninist/Marxiste-Léniniste
# 15   NDP-New Democratic Party/NPD-Nouveau Parti dé...             NDP
# 16                                          PACT/PRCT
# 17                                      Pirate/Pirate
# 18                                  PC Party/Parti PC
# 19                              Rhinoceros/Rhinocéros
# 20                      Seniors Party/Parti des aînés
# 21                                 The Bridge/Le Lien
# 22                             United Party/Parti Uni
# 23                            Independent/Indépendant
# 24                 No Affiliation/Aucune appartenance

# %%
voting_results_df = pd.read_csv(voting_results_fname)

# %%
voting_results_df['Short Name (fr)'] = voting_results_df['Elected Candidate/Candidat élu'].map(lambda s: s.rsplit('/')[-1])
winning_parties_s = voting_results_df['Short Name (fr)'].unique()
winning_parties_s
# Out:
# array(['Libéral', 'NPD-Nouveau Parti démocratique', 'Conservateur',
#        'Bloc Québécois', 'Parti Vert'], dtype=object)

# %%
winning_parties_df = parties_df.loc[parties_df['Short Name (fr)'].isin(winning_parties_s)]
winning_parties_df.to_csv(winners_fname, index=False, encoding='utf-8')
winning_parties_df
# Out:
#      Id                Long Name (en)                Long Name (fr)  \
# 2    BC                Bloc Québécois                Bloc Québécois
# 7   CPC  Conservative Party of Canada  Parti conservateur du Canada
# 10  GRN         Green Party of Canada       Le Parti Vert du Canada
# 11  LIB       Liberal Party of Canada       Parti libéral du Canada
# 15  NDP          New Democratic Party    Nouveau Parti démocratique
#
#                    Short Name (fr)           Short Name (en)  \
# 2                   Bloc Québécois            Bloc Québécois
# 7                     Conservateur              Conservative
# 10                      Parti Vert               Green Party
# 11                         Libéral                   Liberal
# 15  NPD-Nouveau Parti démocratique  NDP-New Democratic Party
#
#                                      Candidate Suffix     Custom Name
# 2                       Bloc Québécois/Bloc Québécois  Bloc Québécois
# 7                           Conservative/Conservateur    Conservative
# 10                             Green Party/Parti Vert     Green Party
# 11                                    Liberal/Libéral         Liberal
# 15   NDP-New Democratic Party/NPD-Nouveau Parti dé...             NDP
