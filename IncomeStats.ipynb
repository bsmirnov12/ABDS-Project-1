# 15                Nova Scotia              Cumberland--Colchester     82321.0
# 16                Nova Scotia             Dartmouth--Cole Harbour     91212.0
# 17                Nova Scotia                             Halifax     92643.0
# 18                Nova Scotia                        Halifax West     87275.0
# 19                Nova Scotia                        Kings--Hants     83306.0
#
#     Electors  Polling Stations  Valid Ballots  Percentage of Valid Ballots  \
# 0    68487.0             220.0        42086.0                         99.6
# 1    62462.0             260.0        35092.0                         99.5
# 2    64226.0             233.0        35448.0                         99.6
# 3    20045.0              84.0        12373.0                         99.6
# 4    71918.0             253.0        41824.0                         99.7
# 5    66304.0             186.0        44880.0                         99.8
# 6    67596.0             185.0        44801.0                         99.7
# 7        NaN               NaN            NaN                          NaN
# 8    28889.0              90.0        22485.0                         99.6
# 9    28129.0              82.0        21165.0                         99.5
# 10   27858.0              86.0        21362.0                         99.6
# 11   28629.0              81.0        22472.0                         99.5
# 12       NaN               NaN            NaN                          NaN
# 13   60785.0             218.0        43237.0                         99.4
# 14   60594.0             224.0        44263.0                         99.5
# 15   65461.0             218.0        46332.0                         99.6
# 16   73710.0             200.0        52270.0                         99.6
# 17   73379.0             208.0        53032.0                         99.5
# 18   70515.0             238.0        50079.0                         99.6
# 19   67213.0             218.0        46686.0                         99.6
#
#     Rejected Ballots  Percentage of Rejected Ballots  Total Ballots Cast  \
# 0              162.0                             0.4             42248.0
# 1              173.0                             0.5             35265.0
# 2              145.0                             0.4             35593.0
# 3               53.0                             0.4             12426.0
# 4              108.0                             0.3             41932.0
# 5              111.0                             0.2             44991.0
# 6              133.0                             0.3             44934.0
# 7                NaN                             NaN                 NaN
# 8               96.0                             0.4             22581.0
# 9               99.0                             0.5             21264.0
# 10              87.0                             0.4             21449.0
# 11             102.0                             0.5             22574.0
# 12               NaN                             NaN                 NaN
# 13             274.0                             0.6             43511.0
# 14             233.0                             0.5             44496.0
# 15             178.0                             0.4             46510.0
# 16             201.0                             0.4             52471.0
# 17             259.0                             0.5             53291.0
# 18             181.0                             0.4             50260.0
# 19             202.0                             0.4             46888.0
#
#     Percentage of Voter Turnout Party Won
# 0                          61.7   Liberal
# 1                          56.5   Liberal
# 2                          55.4   Liberal
# 3                          62.0   Liberal
# 4                          58.3   Liberal
# 5                          67.9   Liberal
# 6                          66.5   Liberal
# 7                           NaN       NaN
# 8                          78.2   Liberal
# 9                          75.6   Liberal
# 10                         77.0   Liberal
# 11                         78.9   Liberal
# 12                          NaN       NaN
# 13                         71.6   Liberal
# 14                         73.4   Liberal
# 15                         71.0   Liberal
# 16                         71.2   Liberal
# 17                         72.6   Liberal
# 18                         71.3   Liberal
# 19                         69.8   Liberal

# %%
df2=df[["Federal Electoral Districts_x", "Income per Resident", "Party Won"]]
df2
# Out:
#           Federal Electoral Districts_x  Income per Resident Party Won
# 0                                Avalon          47560.93294   Liberal
# 1             Bonavista--Burin--Trinity          37797.04251   Liberal
# 2    Coast of Bays--Central--Notre Dame          37740.94887   Liberal
# 3                              Labrador          56132.88526   Liberal
# 4                  Long Range Mountains          37727.15858   Liberal
# ..                                  ...                  ...       ...
# 347               Northwest Territories          59276.95202   Liberal
# 348                                 NaN          59276.95202       NaN
# 349                             Nunavut          48500.41978   Liberal
# 350                                 NaN          48500.41978       NaN
# 351                                 NaN          47222.08024       NaN
#
# [352 rows x 3 columns]

# %%
df3 = df2.dropna()

# %%
fig = df2.boxplot("Income per Resident", by="Party Won", figsize=(20, 10))
fig.figure.savefig("./PNG_images_stats/Income.png", tranparent = True)

# %%
group1 = df2[df2["Party Won"] == "Bloc Québécois"]["Income per Resident"]
group2 = df2[df2["Party Won"] == "Conservative"]["Income per Resident"]
group3 = df2[df2["Party Won"] == "Green Party"]["Income per Resident"]
group4 = df2[df2["Party Won"] == "Liberal"]["Income per Resident"]
group5 = df2[df2["Party Won"] == "NDP"]["Income per Resident"]

# %%
Liberal = df2.loc[df2["Party Won"] == "Liberal"]
Conservative =df2.loc[df2["Party Won"] == "Conservative"]
NDP = df2.loc[df2["Party Won"] == "NDP"]
Bloc = df2.loc[df2["Party Won"] == "Bloc Québécois"]
Bloc
# Out:
#                 Federal Electoral Districts_x  Income per Resident  \
# 44                 Bécancour--Nicolet--Saurel          37909.99360
# 49   Pierre-Boucher--Les Patriotes--Verchères          56405.39944
# 66                                   Joliette          36331.23925
# 68                         La Pointe-de-l'Île          38074.30539
# 81                                Manicouagan          42254.19206
# 83                                    Mirabel          43480.88586
# 85                                   Montcalm          39292.19223
# 95                                 Repentigny          45224.79269
# 98                            Rivière-du-Nord          38811.33231
# 110                                Terrebonne          45013.14946
#
#           Party Won
# 44   Bloc Québécois
# 49   Bloc Québécois
# 66   Bloc Québécois
# 68   Bloc Québécois
# 81   Bloc Québécois
# 83   Bloc Québécois
# 85   Bloc Québécois
# 95   Bloc Québécois
# 98   Bloc Québécois
# 110  Bloc Québécois

# %%
#fig=plt.figure(figsize=(8,3))
fig,ax = plt.subplots(figsize=(5,4))
box_plot_data=[Liberal["Income per Resident"], Conservative["Income per Resident"],NDP["Income per Resident"],Bloc["Income per Resident"]]
x_label_list = ["Liberal", "Conservative", "NDP","Bloc",]
ax.set_xticklabels(x_label_list)
c="red"
c1="blue"
c2="orange"
c3="lightblue"
ax.set_ylim([20000,105700])
plt.boxplot(box_plot_data[0], positions=[0],widths = 0.6, notch=True, patch_artist=True, boxprops=dict(facecolor=c, color=c),capprops=dict(color=c), whiskerprops=dict(color=c), flierprops=dict(color=c, markeredgecolor=c),medianprops=dict(color=c))
plt.boxplot(box_plot_data[1], positions=[1],widths = 0.6, notch=True, patch_artist=True, boxprops=dict(facecolor=c1, color=c1),capprops=dict(color=c1), whiskerprops=dict(color=c1), flierprops=dict(color=c1, markeredgecolor=c1),medianprops=dict(color=c1))
plt.boxplot(box_plot_data[2], positions=[2], widths = 0.6,notch=True, patch_artist=True, boxprops=dict(facecolor=c2, color=c2),capprops=dict(color=c2), whiskerprops=dict(color=c2), flierprops=dict(color=c2, markeredgecolor=c2),medianprops=dict(color=c2))
plt.boxplot(box_plot_data[3], positions=[3],widths = 0.6, notch=True, patch_artist=True, boxprops=dict(facecolor=c3, color=c3),capprops=dict(color=c3), whiskerprops=dict(color=c3), flierprops=dict(color=c3, markeredgecolor=c3),medianprops=dict(color=c3))

#ax.set_xlabel = "Age Groups"
#ax.set_ylabel = "Number of Voters"
#ax.set_title = "Liberal Ridings Analyzed by Age"
plt.xlabel("Party")
plt.ylabel("Income per Resident")
plt.title("Turnout Analyzed by Party")
plt.savefig("./PNG_images_stats/Income4party.png", transparent = True)
plt.show()

# %%
stats.f_oneway(group1, group2, group3, group4, group5)
# Out:
# F_onewayResult(statistic=3.956465559062812, pvalue=0.0037565220061838546)

# %%
stats.f_oneway(group1, group2, group4, group5)
# Out:
# F_onewayResult(statistic=5.13562724628587, pvalue=0.0017465880357847884)
